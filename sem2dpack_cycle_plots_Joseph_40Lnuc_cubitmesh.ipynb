# %% [markdown]
# # Plots for 40Lnuc model using cubit mesh
# * Fault size ~ 40Lnuc
# * fault ~30 times longer than Kaneko's
# * Mesh is made with cubit, with elements of ~10 m (or less) around the fault, and coarser gradually off-fault

# %%
# %matplotlib inline

import sys
import matplotlib.pyplot as plt

sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')

from Class_sem2dpack import *

# %% [markdown]
# # Read outputs

# %%
# Create class with the simulation directory
# path-to-simulation-directory
_dir = '/Users/elifo/Work/Cycles/RateState_testing_josephs_40Lnuc_refined_10m_optim/'

# init class
SEM = sem2dpack(_dir, read_header=False)


# Model coordinates
x, z = SEM.mdict['coord'][:,0],  SEM.mdict['coord'][:,1]
    
# x.shape, z.shape
# x: along dip (for strike-slip here)
# Out:
# Reading grid information...
# *

# %%
SEM.read_fault(is_rate_and_state=True)
# Out:
# Fault boundary:  [3]
# Guessed array size, nsamp:  148896.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# /Users/elifo/Work/Cycles/RateState_testing_josephs_40Lnuc_refined_10m_optim///Flt03_time_sem2d.tab

# %% [markdown]
# # Plot time step evolution

# %%
SEM.plot_cycles_time_step()
# Out:
# Min time step (s):  7.477186690787447e-05
# Max time step (s):  728419.8130241709

# %% [markdown]
# # Plot cumulative slip

# %%
# SEM.plot_cycles_cumulative_slip(VW_halflen=1900.0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/elifo/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-3f75f0145831>", line 1, in <module>
#     SEM.plot_cycles_cumulative_slip(VW_halflen=1900.0)
#   File "/Users/elifo/Work/Cycles/testing_cycle_examples/Class_sem2dpack.py", line 829, in plot_cycles_cumulative_slip
#     plt.plot(self.fault['Slip'][:, ii], self.fault['x'], c=col)
#   File "/Users/elifo/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 2789, in plot
#     is not None else {}), **kwargs)
#   File "/Users/elifo/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py", line 1668, in plot
#     self.add_line(line)
# ...

# %% [markdown]
# # 2D plot of slip rate for a chosen earthquake

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  102.65892

# %%
SEM.plot_cycles_slip_rate(eq=1, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.015511065

# %%
SEM.plot_cycles_slip_rate(eq=2, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010015691
# /Users/elifo/Work/Cycles/testing_cycle_examples/Class_sem2dpack.py:903: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   interpolation='nearest', cmap='rainbow', aspect='auto', vmin=_vmin, vmax=_vmax, origin='lower')

# %%
SEM.plot_cycles_slip_rate(eq=3, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.011805534

# %%
SEM.plot_cycles_slip_rate(eq=4, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  10.280388

# %%
SEM.plot_cycles_slip_rate(eq=5, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  12.618565

# %%
SEM.plot_cycles_slip_rate(eq=6, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  9.030376

# %%
SEM.plot_cycles_slip_rate(eq=7, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010000076

# %%
SEM.plot_cycles_slip_rate(eq=8, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  256.3642

# %%
SEM.plot_cycles_slip_rate(eq=9, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  104.489426

# %%
SEM.plot_cycles_slip_rate(eq=10, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.01224841

# %%
SEM.plot_cycles_slip_rate(eq=11, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.012501333

# %%
SEM.plot_cycles_slip_rate(eq=12, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.0102972

# %%
SEM.plot_cycles_slip_rate(eq=13, is_normalisation=False, VW_halflen=6000.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  2.2801693e+29
