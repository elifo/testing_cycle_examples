# %% [markdown]
# # 10L damage model
#
# * Lnuc = 24.19
# * Lb = 2.33
# * Length = [-360, 360]
# * Width = [0, 240]
# * VS limits = [-240, 240]
# * VW limits = [-120, 120]
# * Damage thickness (one-sided) = 3 --> delta=90%; 2H/Lvw=1/40
# * Cubit mesh with element size range=1-32
# * NO overstressed patch
# * Selected event number = 3

# %%
# %matplotlib notebook
# %matplotlib inline 
import sys
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')
from Class_sem2dpack import *

# %% [markdown]
# # Read output files

# %%
SEM = sem2dpack('../../latest_tests/latest_tests_for_joseph3/10L_DAMAGE_snap/', read_header=False)
SEM.read_fault(is_rate_and_state=True)
# Out:
# Reading grid information...
# *
# Fault boundary:  [3]
# Guessed array size, nsamp:  62088.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# ../../latest_tests/latest_tests_for_joseph3/10L_DAMAGE_snap///Flt03_time_sem2d.tab
# Number of dynamic beginning and ending points: 5 5

# %%
SEM.plot_cycles_time_step()

# %% [markdown]
# # Cumulative slip

# %%
# # Static interval (by input file): jump_sta* 5 years
# # Dynamic interval(""): jump_dyn* 5e-3 seconds
SEM.VW_halflen = 120.
SEM.plot_cycles_cumulative_slip(VW_halflen=SEM.VW_halflen, jump_sta=1,jump_dyn=20)
# Out:
# WARNING: If weird output, try a smaller jump!
# shape of slip,sta,dyn:  (1963, 62088) (1963, 7) (1963, 3105)

# %% [markdown]
# # Space-time plot for slip rate
# * Nucleation close to two edges.

# %%
SEM.plot_cycles_slip_rate(eq=3, is_normalisation=False, VW_halflen=SEM.VW_halflen, _vmax=2, tmin=6,tmax=7)
# Out:
# Number of dynamic beginning and ending points: 5 5
# Max slip rate:  10.0
# Plotting ...
# *
