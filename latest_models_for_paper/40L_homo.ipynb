# %% [markdown]
# # 40L homo model
#
# * Lnuc = 241.92
# * Lb = 23.25
# * Length = [-14520, 14520]
# * Width = [0, 9680]
# * VS limits = [-9680, 9680]
# * VW limits = [-4840, 4840]
# * Cubit mesh
# * NO overstressed patch
# * Selected event number = 18

# %%
# %matplotlib notebook
# %matplotlib inline 
import sys
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')
from Class_sem2dpack import *

# %% [markdown]
# # Read output files

# %%
SEM = sem2dpack('../../latest_tests/latest_tests_for_joseph2/40L_HOMO_nooverstressed//', read_header=False)
SEM.read_fault(is_rate_and_state=True)
# Out:
# Reading grid information...
# *
# Fault boundary:  [3]
# Guessed array size, nsamp:  46222.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# ../../latest_tests/latest_tests_for_joseph2/40L_HOMO_nooverstressed////Flt03_time_sem2d.tab
# Number of dynamic beginning and ending points: 21 21

# %%
SEM.plot_cycles_time_step()

# %% [markdown]
# # Cumulative slip

# %%
# # Static interval (by input file): jump_sta* 5 years
# # Dynamic interval(""): jump_dyn* 5e-3 seconds
SEM.VW_halflen = 4840.
SEM.plot_cycles_cumulative_slip(VW_halflen=SEM.VW_halflen, jump_sta=1,jump_dyn=20)
# Out:
# WARNING: If weird output, try a smaller jump!
# shape of slip,sta,dyn:  (7680, 46221) (7680, 84) (7680, 2307)

# %% [markdown]
# # Space-time plot for slip rate
# * No overstressed patch. Nucleation happens at edge because of tectonic loading.

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=False, VW_halflen=SEM.VW_halflen,_vmax=2.0,tmax=10)
# Out:
# Number of dynamic beginning and ending points: 21 21
# Max slip rate:  10.0
# Plotting ...
# *

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=True, VW_halflen=SEM.VW_halflen,_vmax=12.0,tmax=10)
# Out:
# Number of dynamic beginning and ending points: 21 21
# Max slip rate:  10.0
# Plotting ...
# *

# %% [markdown]
# ### Selected event with visible pulse-like pattern
# * with/out normalisation

# %%
SEM.plot_cycles_slip_rate(eq=18, is_normalisation=False, VW_halflen=SEM.VW_halflen,_vmax=2.0,tmax=10)
# Out:
# Number of dynamic beginning and ending points: 21 21
# Max slip rate:  10.0
# Plotting ...
# *

# %%
SEM.plot_cycles_slip_rate(eq=18, is_normalisation=True, VW_halflen=SEM.VW_halflen,_vmax=12.0,tmax=10)
# Out:
# Number of dynamic beginning and ending points: 21 21
# Max slip rate:  10.0
# Plotting ...
# *
