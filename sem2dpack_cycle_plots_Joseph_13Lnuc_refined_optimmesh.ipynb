# %% [markdown]
# # Plots for 13Lnuc model using cubit mesh
# * Fault size ~ 13Lnuc
# * fault 10 times longer than Kaneko's
# * Mesh is made with cubit, with elements of ~10 m (or less) around the fault, and coarser gradually off-fault

# %%
# %matplotlib inline

import sys
import matplotlib.pyplot as plt

sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')

from Class_sem2dpack import *

# %% [markdown]
# # Read outputs

# %%
# Create class with the simulation directory
# path-to-simulation-directory
_dir = '../RateState_testing_josephs_13Lnuc_refined_10m_optim/'

# init class
SEM = sem2dpack(_dir, read_header=False)


# Model coordinates
x, z = SEM.mdict['coord'][:,0],  SEM.mdict['coord'][:,1]

# x.shape, z.shape
# x: along dip (for strike-slip here)
# Out:
# Reading grid information...
# *

# %%
SEM.read_fault(is_rate_and_state=True)
# Out:
# Fault boundary:  [3]
# Guessed array size, nsamp:  175981.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# ../RateState_testing_josephs_13Lnuc_refined_10m_optim///Flt03_time_sem2d.tab

# %% [markdown]
# # Plot time step evolution

# %%
SEM.plot_cycles_time_step()
# Out:
# Min time step (s):  7.477186690790072e-05
# Max time step (s):  470258.6278640442

# %% [markdown]
# # 2D plot of slip rate for a chosen earthquake

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  83.920044

# %%
SEM.plot_cycles_slip_rate(eq=1, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.011259251

# %%
SEM.plot_cycles_slip_rate(eq=2, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010001708
# /Users/elifo/Work/Cycles/testing_cycle_examples/Class_sem2dpack.py:903: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   interpolation='nearest', cmap='rainbow', aspect='auto', vmin=_vmin, vmax=_vmax, origin='lower')

# %%
SEM.plot_cycles_slip_rate(eq=3, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010951997

# %%
SEM.plot_cycles_slip_rate(eq=4, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  48.151943

# %%
SEM.plot_cycles_slip_rate(eq=5, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  6.9257607

# %%
SEM.plot_cycles_slip_rate(eq=6, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  4.855593

# %%
SEM.plot_cycles_slip_rate(eq=7, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.0100019

# %%
SEM.plot_cycles_slip_rate(eq=8, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010896277

# %%
SEM.plot_cycles_slip_rate(eq=9, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  4.674906

# %%
SEM.plot_cycles_slip_rate(eq=10, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  9.068846

# %%
SEM.plot_cycles_slip_rate(eq=11, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  78.36794

# %%
SEM.plot_cycles_slip_rate(eq=12, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  0.010640641

# %%
SEM.plot_cycles_slip_rate(eq=13, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  4.7629633

# %%
SEM.plot_cycles_slip_rate(eq=14, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-2ccb1dd7a346> in <module>
# ----> 1 SEM.plot_cycles_slip_rate(eq=14, is_normalisation=False, VW_halflen=1900.0, _vmin=0.0, _vmax=2.0)
#
# ~/Work/Cycles/testing_cycle_examples/Class_sem2dpack.py in plot_cycles_slip_rate(self, eq, is_normalisation, VW_halflen, _vmin, _vmax, savefig, VS_LVFZ, Lnuc)
#     853       V = self.fault['Slip_Rate'][:, cdt] #npts, nt
#     854       t = self.fault['t'][cdt]
# --> 855       t -= t[0] # init time at zero
#     856
#     857       # Shear stress: beginning vs end
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
