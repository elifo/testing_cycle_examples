# %% [markdown]
# # 10Lnuc model using Joseph's parameters
# I stoppped the simulation manually.
# Total number of events = 16.
# Model set-up:
# * L = [-3630, 3630]
# * W = [0, 2420]
# * VS limits = -2420, +2420
# * VW limits = -1210, +1210
# * Lnuc = 241.92
# * Lb = 23.25
# * Cartesian mesh, dx=dz=20 (nx, nz = 363, 121)
# * Absorbing bc everwhere except fault
# * V_init=6.34d-11

# %%
# %matplotlib notebook
import sys
# 1: modify the path to sem2dpack  
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')
from Class_sem2dpack import *

# %% [markdown]
# # Read output files

# %%
#2: modify the path to simulation folder (with outputs)
SEM = sem2dpack('../../latest_tests/latest_tests_for_joseph1/10L_HOMO_ABSORB_Vinitsmaller//', read_header=False)
SEM.read_fault(is_rate_and_state=True)
SEM.VW_halflen = 1210
# Out:
# Reading grid information...
# *
# Fault boundary:  [1]
# Guessed array size, nsamp:  28794.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# ../../latest_tests/latest_tests_for_joseph1/10L_HOMO_ABSORB_Vinitsmaller////Flt01_time_sem2d.tab
# Number of dynamic beginning and ending points: 17 17

# %%
SEM.plot_cycles_time_step()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# Static interval (by input file): jump_sta* 5 years
# Dynamic interval(""): jump_dyn* 5e-3 seconds
SEM.plot_cycles_cumulative_slip(VW_halflen=SEM.VW_halflen, jump_sta=1,jump_dyn=20)
# Out:
# WARNING: If weird output, try a smaller jump!
# shape of slip,sta,dyn:  (968, 28794) (968, 72) (968, 1437)
# <img src="data:image/png;base64,..." width="800">

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=False, VW_halflen=SEM.VW_halflen, _vmax=2, tmax=4)
# Out:
# Number of dynamic beginning and ending points: 17 17
# Max slip rate:  10.0
# Plotting ...
# <img src="data:image/png;base64,..." width="900">
# *

# %%
SEM.plot_cycles_slip_rate(eq=15, is_normalisation=False, VW_halflen=SEM.VW_halflen, _vmax=2, tmin=1.5,tmax=4)
# Out:
# Number of dynamic beginning and ending points: 17 17
# Max slip rate:  10.0
# Plotting ...
# <img src="data:image/png;base64,..." width="900">
# *
