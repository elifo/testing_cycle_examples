# %% [markdown]
# # Plots for Joseph's parameters
#
# * Fault size similar to Kaneko's model in unit of Lnuc
# * I prepared the mesh with Cubit taht is identical to the cartesian mesh of previous tests.
# * Structured mesh: Very slight differences in decimal only that must be acceptable.
# * Nonstructured mesh: Refinement (dx=dz=5m) around the fault and larger elsewhere: stable simulation. 2D plots look smoother that I should have a closer look later after chacking the longer fault model.

# %%
# %matplotlib inline

import sys
import matplotlib.pyplot as plt

sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/')
sys.path.append('/Users/elifo/Work/SOFT/sem2dpack/JUPYTER/modules/')

from Class_sem2dpack import *

# %% [markdown]
# # Read outputs

# %%
# Create class with the simulation directory
# path-to-simulation-directory
_dir = '/Users/elifo/Desktop/CYCLES/sem2dpack_tests/RateState_testing_josephs_testmesh_refined_CFLsmaller/'

# init class
SEM = sem2dpack(_dir, read_header=False)


# Model coordinates
x, z = SEM.mdict['coord'][:,0],  SEM.mdict['coord'][:,1]

# x.shape, z.shape
# x: along dip (for strike-slip here)
# Out:
# Reading grid information...
# *

# %%
SEM.read_fault(is_rate_and_state=True)
# Out:
# Fault boundary:  [3]
# Guessed array size, nsamp:  25876.0
# Assigning  Slip
# Assigning  Slip_Rate
# Assigning  Shear_Stress
# Assigning  Normal_Stress
# Assigning  Friction
# Assigning  theta
# /Users/elifo/Desktop/CYCLES/sem2dpack_tests/RateState_testing_josephs_testmesh_refined_CFLsmaller///Flt03_time_sem2d.tab

# %% [markdown]
# # Plot time step evolution

# %%
SEM.plot_cycles_time_step()
# Out:
# Min time step (s):  4.984791127193163e-05
# Max time step (s):  942443.4638173264

# %% [markdown]
# # Plot cumulative slip

# %%
SEM.plot_cycles_cumulative_slip(VW_halflen=190.0)

# %% [markdown]
# # 2D plot of slip rate for a chosen earthquake

# %%
SEM.plot_cycles_slip_rate(eq=0, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.9413161

# %%
SEM.plot_cycles_slip_rate(eq=1, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.7366298

# %%
SEM.plot_cycles_slip_rate(eq=2, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.743573

# %%
SEM.plot_cycles_slip_rate(eq=3, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.7406361

# %%
SEM.plot_cycles_slip_rate(eq=4, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.7412015

# %%
SEM.plot_cycles_slip_rate(eq=5, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.7408082

# %%
SEM.plot_cycles_slip_rate(eq=6, is_normalisation=False, VW_halflen=190.0, _vmin=0.0, _vmax=2.0)
# Out:
# Max slip rate:  1.7439923
